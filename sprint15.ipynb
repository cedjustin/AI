# %% [markdown]
# <a href="https://colab.research.google.com/github/cedjustin/AI/blob/master/sprint15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# (1) What kind of method exists in the field of object detection?
#
# SPPnet [1] and Fast R-CNN [2]
#
# > you can find this in the beginning of the paper

# %% [markdown]
# (2) It says "Faster", but what mechanism was used to make it faster?</br>
# An obvious way to accelerate proposal computation is to reimplement it for the GPU
#
# > you can find this in the introduction part

# %% [markdown]
# (3) How is the One-Stage method different from the Two-Stage method?</br>
#
# Overfeat which is a **one-stage** class specific detection, proposes a detection method that uses regressors and classifiers on sliding
# windows over convolutional feature maps.</br>
#
# While a **two-stage** consists of class-agnostic proposals and class-specific detections.
# ![once.png](data:image/png;base64,...)
#
# > 4 EXPERIMENTS

# %% [markdown]
# (4) What is RPN?</br>
# RPN is a network that takes an image
# (of any size) as input and outputs a set of rectangular
# object proposals, each with an objectness score.
#
# To generate region proposals, we slide a small
# network over the convolutional feature map output
# by the last shared convolutional layer. This small
# network takes as input an n × n spatial window of
# the input convolutional feature map.
#
# > 3.1 Region Proposal Networks

# %% [markdown]
# (5) What is RoI pooling?</br>
# Rol pooling is a layer in faster R-CNN.
#
# this layer accepts convolutional features
# and also the predicted bounding boxes as input.
#
# ![once.png](data:image/png;base64,...)
#
# > 3 FASTER R-CNN

# %% [markdown]
# (6) What is the proper size for Anchor?</br>
# An anchor is centered at the sliding window
# in question, and is associated with a scale and aspect
# ratio. **By default we use 3 scales and
# 3 aspect ratios.**
#
# ![once.png](data:image/png;base64,...)
#
# > 3 FASTER R-CNN

# %% [markdown]
# (7) What kind of data set is used and what kind of index value is obtained compared to the previous research?
#
#  PASCAL VOC 2007, 2012, and MS COCO datasets
#
# ![once.png](data:image/png;base64,...)
#
#  > Abstract
